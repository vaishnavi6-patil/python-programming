# %%
#add 2 numbers
a=10
b=20
c=a+b
print(c)

#variables
b=18
print(b)
print(type(b))

d=18.7
print(d)
print(type(d))

e="Hello"
print(e)
print(type(e))

f=[6,7,8]
print(f)
print(type(f))

g=(10,20,30)
print(g)
print(type(g))

h={0,8.6,"football"}
print(h)
print(type(h))

#casting
i=6
j=float(i)
print(j)
print(type(j))

k=(1,2,3,4)
m=list(k)
print(m)
print(type(m))

#logical
n=True
o=False
print(n and o)
print(n or o)
print(not n)
# Out:
# 30
# 18
# <class 'int'>
# 18.7
# <class 'float'>
# Hello
# <class 'str'>
# [6, 7, 8]
# <class 'list'>
# (10, 20, 30)
# <class 'tuple'>
# {0, 8.6, 'football'}
# <class 'set'>
# 6.0
# <class 'float'>
# [1, 2, 3, 4]
# <class 'list'>
# False
# True
# False
